# %% [markdown]
# <a href="https://colab.research.google.com/github/matheusmoura-stack/Testes__Numpy-Pandas/blob/main/test002.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import pandas as pd

# %%
#Criação de Dataframes a partir de um array!

# %%
arr = np.random.randint(10,55,size=(4,4))

# %%
arr
# Out:
# array([[20, 29, 41, 15],
#        [32, 32, 21, 18],
#        [19, 41, 40, 36],
#        [39, 20, 35, 14]])

# %%
df1 = pd.DataFrame(data=arr, index=['a','b','c','d'], columns=['w','x','y','z'])

# %%
df1
# Out:
#     w   x   y   z
# a  20  29  41  15
# b  32  32  21  18
# c  19  41  40  36
# d  39  20  35  14

# %%
#Criação de DataFrames a partir de Listas

# %%
lista = [[10,20,30,40],[50,60,70,80]]

# %%
df2 = pd.DataFrame(data=lista)

# %%
df2
# Out:
#     0   1   2   3
# 0  10  20  30  40
# 1  50  60  70  80

# %%
#Criação de DataFrames através de um dicionário

# %%
dados = {'produtos': ['VideoGame', 'PC','Teclado','Microfone'],'preço':[2600, 4500, 220, 180]}

# %%
df3 = pd.DataFrame(data = dados)

# %%
df3
# Out:
#     produtos  preço
# 0  VideoGame   2600
# 1         PC   4500
# 2    Teclado    220
# 3  Microfone    180

# %%
#Criando uma nova coluna

# %%
df3['custo'] = [1900,2600,250,160]

# %%
df2
# Out:
#     0   1   2   3
# 0  10  20  30  40
# 1  50  60  70  80

# %%
df3
# Out:
#     produtos  preço  custo
# 0  VideoGame   2600   1900
# 1         PC   4500   2600
# 2    Teclado    220    250
# 3  Microfone    180    160

# %%
df3['Lucro'] = df3['preço'] - df3['custo']

# %%
df3
# Out:
#     produtos  preço  custo  Lucro
# 0  VideoGame   2600   1900    700
# 1         PC   4500   2600   1900
# 2    Teclado    220    250    -30
# 3  Microfone    180    160     20
