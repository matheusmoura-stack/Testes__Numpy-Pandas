# %% [markdown]
# <a href="https://colab.research.google.com/github/matheusmoura-stack/Testes__Numpy-Pandas/blob/main/test004.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import pandas as pd

# %%
lista = [['BRASIL', 'BRASIL', 'BRASIL','ARGENTINA','ARGENTINA','ARGENTINA'],[2017,2018,2019,2017,2018,2019]]

# %%
tupla = zip(*lista)

# %%
tupla

# %%
tupla = list(tupla)

# %%
tupla
# Out:
# [('BRASIL', 2017),
#  ('BRASIL', 2018),
#  ('BRASIL', 2019),
#  ('ARGENTINA', 2017),
#  ('ARGENTINA', 2018),
#  ('ARGENTINA', 2019)]

# %%
multi = pd.MultiIndex.from_tuples(tupla)

# %%
multi
# Out:
# MultiIndex([(   'BRASIL', 2017),
#             (   'BRASIL', 2018),
#             (   'BRASIL', 2019),
#             ('ARGENTINA', 2017),
#             ('ARGENTINA', 2018),
#             ('ARGENTINA', 2019)],
#            )

# %%
df = pd.DataFrame(data = np.random.randn(6,2), index = multi, columns = ['EX DE TRIGO','EX DE ARROZ'])

# %%
df
# Out:
#                 EX DE TRIGO  EX DE ARROZ
# PAÍS      ANO
# BRASIL    2017     1.722615     0.838389
#           2018     1.463552    -0.552272
#           2019    -0.211115     1.092652
# ARGENTINA 2017     1.221460     0.132325
#           2018     0.231269    -0.043972
#           2019    -0.376156    -0.837115

# %%
df.index.names = ['PAÍS', 'ANO']

# %%
df
# Out:
#                 EX DE TRIGO  EX DE ARROZ
# PAÍS      ANO
# BRASIL    2017     1.722615     0.838389
#           2018     1.463552    -0.552272
#           2019    -0.211115     1.092652
# ARGENTINA 2017     1.221460     0.132325
#           2018     0.231269    -0.043972
#           2019    -0.376156    -0.837115

# %%
#ENCONTRANDO VALORES

# %%
df['EX DE ARROZ']
# Out:
# PAÍS       ANO
# BRASIL     2017    0.838389
#            2018   -0.552272
#            2019    1.092652
# ARGENTINA  2017    0.132325
#            2018   -0.043972
#            2019   -0.837115
# Name: EX DE ARROZ, dtype: float64

# %%
df.loc['BRASIL']
# Out:
#       EX DE TRIGO  EX DE ARROZ
# ANO
# 2017     1.722615     0.838389
# 2018     1.463552    -0.552272
# 2019    -0.211115     1.092652

# %%
df.xs(2017,level=1)
# Out:
#            EX DE TRIGO  EX DE ARROZ
# PAÍS
# BRASIL        1.722615     0.838389
# ARGENTINA     1.221460     0.132325

# %%
df[:]
# Out:
#                 EX DE TRIGO  EX DE ARROZ
# PAÍS      ANO
# BRASIL    2017     1.722615     0.838389
#           2018     1.463552    -0.552272
#           2019    -0.211115     1.092652
# ARGENTINA 2017     1.221460     0.132325
#           2018     0.231269    -0.043972
#           2019    -0.376156    -0.837115

# %%
df[4:]
# Out:
#                 EX DE TRIGO  EX DE ARROZ
# PAÍS      ANO
# ARGENTINA 2018     0.231269    -0.043972
#           2019    -0.376156    -0.837115

# %%
df[3:]
# Out:
#                 EX DE TRIGO  EX DE ARROZ
# PAÍS      ANO
# ARGENTINA 2017     1.221460     0.132325
#           2018     0.231269    -0.043972
#           2019    -0.376156    -0.837115

# %%
df[:4]
# Out:
#                 EX DE TRIGO  EX DE ARROZ
# PAÍS      ANO
# BRASIL    2017     1.722615     0.838389
#           2018     1.463552    -0.552272
#           2019    -0.211115     1.092652
# ARGENTINA 2017     1.221460     0.132325

# %%
df[:3]
# Out:
#              EX DE TRIGO  EX DE ARROZ
# PAÍS   ANO
# BRASIL 2017     1.722615     0.838389
#        2018     1.463552    -0.552272
#        2019    -0.211115     1.092652

# %%
df
# Out:
#                 EX DE TRIGO  EX DE ARROZ
# PAÍS      ANO
# BRASIL    2017     1.722615     0.838389
#           2018     1.463552    -0.552272
#           2019    -0.211115     1.092652
# ARGENTINA 2017     1.221460     0.132325
#           2018     0.231269    -0.043972
#           2019    -0.376156    -0.837115

# %%
df[['EX DE TRIGO','EX DE ARROZ']]
# Out:
#                 EX DE TRIGO  EX DE ARROZ
# PAÍS      ANO
# BRASIL    2017     1.722615     0.838389
#           2018     1.463552    -0.552272
#           2019    -0.211115     1.092652
# ARGENTINA 2017     1.221460     0.132325
#           2018     0.231269    -0.043972
#           2019    -0.376156    -0.837115

# %%
#Vendo o DataFrame de outro jeito

# %%
df2 = df.unstack()

# %%
df2
# Out:
#           EX DE TRIGO                     EX DE ARROZ
# ANO              2017      2018      2019        2017      2018      2019
# PAÍS
# ARGENTINA    1.221460  0.231269 -0.376156    0.132325 -0.043972 -0.837115
# BRASIL       1.722615  1.463552 -0.211115    0.838389 -0.552272  1.092652
